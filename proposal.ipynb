# %% [markdown]
# ### Intro
#
# Video games have long since been a staple of pop culture. But, what determines which games get their 15 minutes of fame, which games are loved, and which are hated? To determine such a thing, there are several statistics and metrics available to look at. It's possible to look at data from Steam, a massively popular website used for purchasing such games. Steam offers a treasure trove of information regarding the genres of a game, the popularity and player count, historical price information, and much more that can be used to identify when a game does well, and how other factors correlate. Another good question to ask is where? Where are the most famous games, on average made? Does this have any larger commentaries?

# %% [markdown]
# ### Data Collection
#
#
# I plan to use Steam's API to access all of this information. I plan to collect data from 30 games from the top 100 games by concurrent players to analyze, looking at everything from average player count, prices, genres, ratings, and more.

# %%
import pandas as pd
import numpy as np
import requests
import json


url = "https://api.steampowered.com/ISteamChartsService/GetMostPlayedGames/v1/"
#request steam API to get the most played games
response = requests.get(url)

#Get the json from the request
json_info = response.json()

#Create new data frame
df_games = pd.DataFrame()

#Collect data from the top 30 games by current players on steam.
for i in json_info['response']['ranks']:
    url = "http://store.steampowered.com/api/appdetails?appids="+str(i['appid'])+"&cc=us"
    appid = i['appid']
    curr = requests.get(url).json()[str(appid)]

    #add peak players to data
    curr['data']['peak_players'] = i['peak_in_game']


    #put into data frame
    df_games = pd.concat([df_games, pd.DataFrame({i['rank'] : curr['data']})], axis=1)

    #If we've gone past the 30th highest ranked game, break.
    if (i['rank'] >= 30):
        break

df_games = df_games.T

#select only the proper columns wanted
df_games = df_games[['type','name','steam_appid','is_free','ratings','price_overview','peak_players']]

df_games
# Out:
#     type                               name steam_appid is_free  \
# 1   game                   Counter-Strike 2         730    True
# 2   game                             Dota 2         570    True
# 3   game                PUBG: BATTLEGROUNDS      578080    True
# 4   game                   Wallpaper Engine      431960   False
# 5   game            Hollow Knight: Silksong     1030300   False
# 6   game                      Apex Legends™     1172470    True
# 7   game                      Marvel Rivals     2767030    True
# 8   game                        Delta Force     2507950    True
# 9   game                             skate.     3354750    True
# 10  game                           Megabonk     3405340   False
# 11  game                        War Thunder      236390    True
# 12  game                     Stardew Valley      413150   False
# 13  game                      Call of Duty®     1938090   False
# 14  game                   Dead by Daylight      381210   False
# 15  game                 NARAKA: BLADEPOINT     1203220    True
# 16  game                               Rust      252490   False
# 17  game                      HELLDIVERS™ 2      553850   False
# 18  game                      Borderlands 4     1285190   False
# 19  game  Tom Clancy's Rainbow Six® Siege X      359550    True
# 20  game                           Terraria      105600   False
# 21  game                      Left 4 Dead 2         550   False
# 22  game          Grand Theft Auto V Legacy      271590   False
# 23  game                           Hades II     1145350   False
# 24  game                               PEAK     3527290   False
# 25  game               Monster Hunter Wilds     2246340   False
# 26  game        Grand Theft Auto V Enhanced     3240220   False
# 27  game             Euro Truck Simulator 2      227300   False
# 28  game                    Baldur's Gate 3     1086940   False
# 29  game                   EA SPORTS FC™ 26     3405690   False
# 30  game                     Limbus Company     1973530    True
#
#                                               ratings  \
# 1   {'usk': {'rating': '16', 'descriptors': 'Gewal...
# 2   {'kgrb': {'rating': '12', 'descriptors': '12 (...
# 3   {'kgrb': {'rating': '18', 'descriptors': '폭력성'...
# 4   {'dejus': {'rating_generated': '1', 'rating': ...
# 5   {'dejus': {'rating_generated': '1', 'rating': ...
# 6   {'esrb': {'rating': 't', 'descriptors': 'Blood...
# 7   {'kgrb': {'rating': '15', 'descriptors': '폭력성,...
# 8   {'dejus': {'rating_generated': '1', 'rating': ...
# 9   {'esrb': {'rating': 't', 'descriptors': 'Lyric...
# 10  {'dejus': {'rating_generated': '1', 'rating': ...
# 11  {'esrb': {'rating': 't'}, 'pegi': {'rating': '...
# 12  {'esrb': {'rating': 'e10', 'descriptors': 'Fan...
# 13  {'dejus': {'rating': '18', 'use_age_gate': 'tr...
# 14  {'esrb': {'rating': 'm', 'descriptors': 'Blood...
# 15  {'dejus': {'rating': '12', 'descriptors': 'Vio...
# 16  {'esrb': {'use_age_gate': 'true', 'required_ag...
# 17  {'esrb': {'rating': 'm', 'use_age_gate': 'true...
# 18  {'esrb': {'rating': 'm', 'display_online_notic...
# 19  {'pegi': {'rating': '18', 'descriptors': 'Viol...
# 20  {'dejus': {'rating_generated': '1', 'rating': ...
# 21  {'oflc': {'rating': 'r18', 'use_age_gate': 'tr...
# 22  {'esrb': {'rating': 'm', 'use_age_gate': 'true...
# 23  {'dejus': {'rating': '14', 'descriptors': 'Vio...
# 24  {'dejus': {'rating_generated': '1', 'rating': ...
# 25  {'esrb': {'rating': 't', 'descriptors': 'Viole...
# 26  {'esrb': {'rating': 'm', 'descriptors': 'Inten...
# 27  {'pegi': {'rating': '3'}, 'usk': {'rating': '0...
# 28  {'esrb': {'rating': 'm', 'descriptors': 'Inten...
# 29  {'esrb': {'rating': 'e', 'interactive_elements...
# 30  {'kgrb': {'rating': '18', 'use_age_gate': 'tru...
#
#                                        price_overview peak_players
# 1                                                 NaN      1389582
# 2                                                 NaN       847561
# 3                                                 NaN       579865
# 4   {'currency': 'USD', 'initial': 499, 'final': 3...       141646
# 5   {'currency': 'USD', 'initial': 1999, 'final': ...       139668
# 6                                                 NaN       149420
# 7                                                 NaN        95496
# 8                                                 NaN       207907
# 9                                                 NaN        76319
# 10  {'currency': 'USD', 'initial': 999, 'final': 9...       117336
# 11                                                NaN        90184
# 12  {'currency': 'USD', 'initial': 1499, 'final': ...       128824
# 13                                                NaN        99574
# 14  {'currency': 'USD', 'initial': 1999, 'final': ...        81342
# 15                                                NaN       102727
# 16  {'currency': 'USD', 'initial': 3999, 'final': ...       171554
# 17  {'currency': 'USD', 'initial': 3999, 'final': ...        62498
# 18  {'currency': 'USD', 'initial': 6999, 'final': ...        97067
# 19                                                NaN        63225
# 20  {'currency': 'USD', 'initial': 999, 'final': 4...        44275
# 21  {'currency': 'USD', 'initial': 999, 'final': 1...        41417
# 22                                                NaN        91906
# 23  {'currency': 'USD', 'initial': 2999, 'final': ...        83351
# 24  {'currency': 'USD', 'initial': 799, 'final': 6...        44016
# 25  {'currency': 'USD', 'initial': 6999, 'final': ...       100224
# 26  {'currency': 'USD', 'initial': 2999, 'final': ...        71167
# 27  {'currency': 'USD', 'initial': 1999, 'final': ...        58392
# 28  {'currency': 'USD', 'initial': 5999, 'final': ...        87538
# 29  {'currency': 'USD', 'initial': 6999, 'final': ...        92958
# 30                                                NaN        46827

# %% [markdown]
# From these numbers, we can use ML and other powerful programming tools to analyze prices, ratings, number of players, release date, and more, and decide if a game is popular, can become popular based on its information. We can analyze prices and peak players then on any game and decide whether or not something must change to make it more successful. Additionally, these numbers can be used to determine if time of year, location of publication, or anything else impacted the game's success.
